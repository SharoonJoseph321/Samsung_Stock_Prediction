# %% [markdown]
# SAMSUNG STOCKS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\Datascience\Projects\Machine_Lrning\data\Samsung.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\sharo\AppData\Local\Temp\ipykernel_5648\1078801524.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('D:\Datascience\Projects\Machine_Lrning\data\Samsung.csv')

# %%
df.head(10)
# Out:
#          Date    Open    High     Low   Close    Adj Close    Volume
# 0  2000-01-04  6000.0  6110.0  5660.0  6110.0  4651.737793  74195000
# 1  2000-01-05  5800.0  6060.0  5520.0  5580.0  4248.232422  74680000
# 2  2000-01-06  5750.0  5780.0  5580.0  5620.0  4278.686523  54390000
# 3  2000-01-07  5560.0  5670.0  5360.0  5540.0  4217.780273  40305000
# 4  2000-01-10  5600.0  5770.0  5580.0  5770.0  4392.884766  46880000
# 5  2000-01-11  5820.0  6100.0  5770.0  5770.0  4392.884766  59745000
# 6  2000-01-12  5610.0  5740.0  5600.0  5720.0  4354.818359  29220000
# 7  2000-01-13  5600.0  5740.0  5560.0  5710.0  4347.205078  41190000
# 8  2000-01-14  5720.0  5880.0  5680.0  5830.0  4438.565918  49375000
# 9  2000-01-17  6000.0  6180.0  5920.0  6100.0  4644.125000  63505000

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   5621.000000   5621.000000   5621.000000   5621.000000   5621.000000
# mean   24884.228785  25135.306885  24627.612524  24879.640633  21729.421164
# std    20108.258909  20274.093474  19934.697294  20094.098853  19740.261271
# min     2540.000000   2760.000000   2420.000000   2730.000000   2078.436279
# 25%    10160.000000  10320.000000  10020.000000  10160.000000   7780.813477
# 50%    16580.000000  16800.000000  16420.000000  16600.000000  13287.424805
# 75%    31320.000000  31600.000000  30940.000000  31340.000000  26643.304688
# max    90300.000000  96800.000000  89500.000000  91000.000000  88908.179688
#
#              Volume
# count  5.621000e+03
# mean   2.176271e+07
# std    1.545201e+07
# min    0.000000e+00
# 25%    1.179815e+07
# 50%    1.774055e+07
# 75%    2.722500e+07
# max    1.642150e+08

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5616    False
# 5617    False
# 5618    False
# 5619    False
# 5620    False
# Length: 5621, dtype: bool

# %%
df['DayOfWeek'] = pd.to_datetime(df['Date']).dt.dayofweek
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df.head(50)
# Out:
#           Date    Open    High     Low   Close    Adj Close     Volume  \
# 0   2000-01-04  6000.0  6110.0  5660.0  6110.0  4651.737793   74195000
# 1   2000-01-05  5800.0  6060.0  5520.0  5580.0  4248.232422   74680000
# 2   2000-01-06  5750.0  5780.0  5580.0  5620.0  4278.686523   54390000
# 3   2000-01-07  5560.0  5670.0  5360.0  5540.0  4217.780273   40305000
# 4   2000-01-10  5600.0  5770.0  5580.0  5770.0  4392.884766   46880000
# 5   2000-01-11  5820.0  6100.0  5770.0  5770.0  4392.884766   59745000
# 6   2000-01-12  5610.0  5740.0  5600.0  5720.0  4354.818359   29220000
# 7   2000-01-13  5600.0  5740.0  5560.0  5710.0  4347.205078   41190000
# 8   2000-01-14  5720.0  5880.0  5680.0  5830.0  4438.565918   49375000
# 9   2000-01-17  6000.0  6180.0  5920.0  6100.0  4644.125000   63505000
# 10  2000-01-18  6160.0  6160.0  5980.0  6100.0  4644.125000   45260000
# 11  2000-01-19  6000.0  6040.0  5960.0  5960.0  4537.538574   40205000
# ...

# %%
df[df['Volume']==0].value_counts()
# Out:
# Date        Open     High     Low      Close    Adj Close     Volume  DayOfWeek  Month
# 2000-02-04  5130.0   5130.0   5130.0   5130.0   3905.632813   0       4          2        1
# 2004-03-01  10900.0  10900.0  10900.0  10900.0  8298.516602   0       0          3        1
# 2005-04-05  10340.0  10340.0  10340.0  10340.0  7872.173828   0       1          4        1
# 2005-03-01  10540.0  10540.0  10540.0  10540.0  8024.441406   0       1          3        1
# 2005-02-10  10200.0  10200.0  10200.0  10200.0  7765.586426   0       3          2        1
#                                                                                          ..
# 2001-10-03  2810.0   2810.0   2810.0   2810.0   2139.343262   0       2          10       1
# 2001-10-02  2810.0   2810.0   2810.0   2810.0   2139.343262   0       1          10       1
# 2001-10-01  2810.0   2810.0   2810.0   2810.0   2139.343262   0       0          10       1
# ...

# %%
df['Volume']=df['Volume'].replace({0:21762707})

# %%
#Assigning Independent(Y) and Dependent variable(X)
x=df[['Open','Low','Close','Adj Close','Volume','DayOfWeek','Month']].values
y=df['High'].values

# %% [markdown]
# Machine Learning (Regression)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df.to_string())
# Out:
#        Actual     Predicted
# 0     46850.0  46786.742109
# 1     46000.0  46264.196125
# 2     11960.0  12041.389432
# 3      7750.0   7751.218155
# 4     10360.0  10350.092987
# 5      2870.0   2854.786410
# 6     51200.0  51389.557372
# 7     25320.0  25371.163320
# 8     15300.0  15377.966670
# 9     25920.0  25896.560795
# 10     3850.0   3878.565508
# 11    49180.0  49345.465255
# 12    13760.0  13727.524979
# 13    12880.0  12842.497175
# 14     2880.0   2817.909682
# 15    31760.0  31746.527228
# 16    30060.0  29726.079749
# 17    29960.0  30199.433943
# 18    50280.0  50503.183260
# 19    12040.0  12060.870940
# 20    12620.0  12571.121936
# 21    47200.0  47647.835005
# 22     3360.0   3308.408782
# 23     5610.0   5600.000641
# 24    11320.0  11404.404518
# 25    43900.0  44174.947439
# 26    43800.0  43706.718816
# 27     4600.0   4512.870838
# 28    26420.0  26425.974767
# 29     7630.0   7664.341983
# 30    19460.0  19569.909041
# 31    26060.0  26269.165825
# ...

# %%
# y_test_flat = y_test.flatten()
# y_pred_flat = y_pred.flatten()
# df2 = pd.DataFrame({'Actual':y_test_flat, 'Predicted': y_pred_flat})

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 107.73089284237166
# Mean Squared Error: 49101.648559958085
# Root Mean Squared Error: 221.58891795385003

# %%
from sklearn.metrics import r2_score
# predicting the accuracy score
score=r2_score(y_test,y_pred)
print("r2 socre is ",score*100,"%")
# Out:
# r2 socre is  99.98703061827833 %

# %%
import numpy as np
import pandas as pd


new_data = {
    'Open': 300.50,
    'Low': 295.30,
    'Close': 298.20,
    'Adj Close': 298.00,
    'Volume': 1500000,
    'DayOfWeek': 2,
    'Month': 9       
}


new_data_df = pd.DataFrame([new_data])



new_data_array = new_data_df.values

# Make prediction using the trained model
predicted_high = regressor.predict(new_data_array)

# Output the prediction
print("Predicted High:", predicted_high[0])
# Out:
# Predicted High: 175.11331570478393
